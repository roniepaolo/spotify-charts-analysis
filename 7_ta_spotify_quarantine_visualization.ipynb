# %% [markdown]
# # Anlyzing Moods

# %% [markdown]
# <img src="https://dl-ta-dataset.s3.amazonaws.com/expo2.png" alt="drawing" width="1000"/>

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import plotly.figure_factory as ff

# %%
# Just for Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df_southamerica_results = pd.read_csv('/content/drive/My Drive/data-analysis-ta-2020/southamerica_results.csv')
df_northamerica_results = pd.read_csv('/content/drive/My Drive/data-analysis-ta-2020/northamerica_results.csv')
df_europe_results = pd.read_csv('/content/drive/My Drive/data-analysis-ta-2020/europe_results.csv')
df_asia_results = pd.read_csv('/content/drive/My Drive/data-analysis-ta-2020/asia_results.csv')
df_africa_results = pd.read_csv('/content/drive/My Drive/data-analysis-ta-2020/africa_results.csv')
df_oceania_results = pd.read_csv('/content/drive/My Drive/data-analysis-ta-2020/oceania_results.csv')
df_peru_results = pd.read_csv('/content/drive/My Drive/data-analysis-ta-2020/peru_results.csv')

# %% [markdown]
# ## Southamerica: Energy per cluster

# %%
df_pie_southamerica = df_southamerica_results.loc[:, ['clusters', 'track_id']].groupby(by='clusters', as_index=False).count()
df_pie_southamerica
# Out:
#    clusters  track_id
# 0         0       545
# 1         1       846
# 2         2       534
# 3         3       241

# %%
labels = ['Cluster 0: Joyful','Cluster 1: Party','Cluster 2: Chill','Cluster 3: Romantic']

fig = go.Figure(
        data=[go.Pie(labels=labels, values=df_pie_southamerica.loc[:, 'track_id'])]
      )


# Add title
fig.update_layout(title_text='Moods in South America')
fig.update_layout({
  'plot_bgcolor': 'rgba(0, 0, 0, 0)',
  'paper_bgcolor': 'rgba(0, 0, 0, 0)',
})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dc126437-d563-4314-a771-7a3e8570032c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dc126437-d563-4314-a771-7a3e8570032c")) {
#                     Plotly.newPlot(
#                         'dc126437-d563-4314-a771-7a3e8570032c',
# ...

# %%
x1 = df_southamerica_results.loc[df_southamerica_results.\
     loc[:, 'clusters'] == 0].loc[:, 'track_energy']
x2 = df_southamerica_results.loc[df_southamerica_results.\
     loc[:, 'clusters'] == 1].loc[:, 'track_energy']
x3 = df_southamerica_results.loc[df_southamerica_results.\
     loc[:, 'clusters'] == 2].loc[:, 'track_energy']
x4 = df_southamerica_results.loc[df_southamerica_results.\
     loc[:, 'clusters'] == 3].loc[:, 'track_energy']

hist_data = [x1, x2, x3, x4]

group_labels = ['Cluster 0: Joyful', 'Cluster 1: Party', 'Cluster 2: Chill', 'Cluster 3: Romantic']
colors = ['#656565', '#808782', '#A6D3A0', '#D1FFD7']

# Create distplot with curve_type set to 'normal'
fig = ff.create_distplot(hist_data, group_labels, colors=colors,
                         bin_size=[0.05, 0.05, 0.05, 0.05], show_hist=True, show_rug=False)

# Add title
fig.update_layout(title_text='Energy in South America per Mood')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5a490e25-91ce-4bf0-9954-d1867732e30c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5a490e25-91ce-4bf0-9954-d1867732e30c")) {
#                     Plotly.newPlot(
#                         '5a490e25-91ce-4bf0-9954-d1867732e30c',
# ...

# %%
x1 = df_southamerica_results.loc[df_southamerica_results.\
     loc[:, 'clusters'] == 0].loc[:, 'track_valence']
x2 = df_southamerica_results.loc[df_southamerica_results.\
     loc[:, 'clusters'] == 1].loc[:, 'track_valence']
x3 = df_southamerica_results.loc[df_southamerica_results.\
     loc[:, 'clusters'] == 2].loc[:, 'track_valence']
x4 = df_southamerica_results.loc[df_southamerica_results.\
     loc[:, 'clusters'] == 3].loc[:, 'track_valence']

hist_data = [x1, x2, x3, x4]

group_labels = ['Cluster 0: Joyful', 'Cluster 1: Party', 'Cluster 2: Chill', 'Cluster 3: Romantic']
colors = ['#656565', '#808782', '#A6D3A0', '#D1FFD7']

# Create distplot with curve_type set to 'normal'
fig = ff.create_distplot(hist_data, group_labels, colors=colors,
                         bin_size=[0.05, 0.05, 0.05, 0.05], show_hist=True, show_rug=False)

# Add title
fig.update_layout(title_text='Valence in South America per Mood')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="efc351d6-c659-40bc-acae-b6310e0635ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("efc351d6-c659-40bc-acae-b6310e0635ac")) {
#                     Plotly.newPlot(
#                         'efc351d6-c659-40bc-acae-b6310e0635ac',
# ...

# %%
x1 = df_southamerica_results.loc[df_southamerica_results.\
     loc[:, 'clusters'] == 0].loc[:, 'track_danceability']
x2 = df_southamerica_results.loc[df_southamerica_results.\
     loc[:, 'clusters'] == 1].loc[:, 'track_danceability']
x3 = df_southamerica_results.loc[df_southamerica_results.\
     loc[:, 'clusters'] == 2].loc[:, 'track_danceability']
x4 = df_southamerica_results.loc[df_southamerica_results.\
     loc[:, 'clusters'] == 3].loc[:, 'track_danceability']

hist_data = [x1, x2, x3, x4]

group_labels = ['Cluster 0: Joyful', 'Cluster 1: Party', 'Cluster 2: Chill', 'Cluster 3: Romantic']
colors = ['#656565', '#808782', '#A6D3A0', '#D1FFD7']

# Create distplot with curve_type set to 'normal'
fig = ff.create_distplot(hist_data, group_labels, colors=colors,
                         bin_size=[0.05, 0.05, 0.05, 0.05], show_hist=True, show_rug=False)

# Add title
fig.update_layout(title_text='Danceability in South America per Mood')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8b05c160-0355-4028-b0e4-587066080eb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8b05c160-0355-4028-b0e4-587066080eb4")) {
#                     Plotly.newPlot(
#                         '8b05c160-0355-4028-b0e4-587066080eb4',
# ...

# %% [markdown]
# ## Peru: Energy per cluster

# %%
df_peru_results = pd.read_csv('https://dl-ta-dataset.s3.amazonaws.com/peru_results.csv')
df_peru_results.head()
# Out:
#   country date_extraction  ... track_danceability clusters
# 0    Peru      2020-01-01  ...              0.661        0
# 1    Peru      2020-01-01  ...              0.763        2
# 2    Peru      2020-01-01  ...              0.769        2
# 3    Peru      2020-01-01  ...              0.549        0
# 4    Peru      2020-01-01  ...              0.661        2
#
# [5 rows x 11 columns]

# %%
df_pie_peru = df_peru_results.loc[:, ['clusters', 'track_id']].groupby(by='clusters', as_index=False).count()
df_pie_peru
# Out:
#    clusters  track_id
# 0         0       113
# 1         1        49
# 2         2       247
# 3         3       148

# %%
labels = ['Cluster 0: Chill','Cluster 1: Romantic','Cluster 2: Party','Cluster 3: Joyful']

fig = go.Figure(
        data=[go.Pie(labels=labels, values=df_pie_peru.loc[:, 'track_id'])]
      )

# Add title
fig.update_layout(title_text='Moods in Peru')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="141f0ac5-84ba-4c6a-9931-eb82b0dc1186" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("141f0ac5-84ba-4c6a-9931-eb82b0dc1186")) {
#                     Plotly.newPlot(
#                         '141f0ac5-84ba-4c6a-9931-eb82b0dc1186',
# ...

# %%
x1_energy = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 0].loc[:, 'track_energy']
x2_energy = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 1].loc[:, 'track_energy']
x3_energy = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 2].loc[:, 'track_energy']
x4_energy = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 3].loc[:, 'track_energy']

hist_data = [x1_energy, x2_energy, x3_energy, x4_energy]

group_labels = ['Cluster 0: Chill','Cluster 1: Romantic','Cluster 2: Party','Cluster 3: Joyful']
colors = ['#656565', '#808782', '#A6D3A0', '#D1FFD7']

# Create distplot with curve_type set to 'normal'
fig = ff.create_distplot(hist_data, group_labels, colors=colors,
                         bin_size=[0.05, 0.05, 0.05, 0.05], show_hist=True, show_rug=False)

# Add title
fig.update_layout(title_text='Energy in Peru')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="590407a3-0cb8-4842-b235-207bf59a069a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("590407a3-0cb8-4842-b235-207bf59a069a")) {
#                     Plotly.newPlot(
#                         '590407a3-0cb8-4842-b235-207bf59a069a',
# ...

# %%
x1 = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 0].loc[:, 'track_valence']
x2 = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 1].loc[:, 'track_valence']
x3 = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 2].loc[:, 'track_valence']
x4 = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 3].loc[:, 'track_valence']

hist_data = [x1, x2, x3, x4]

group_labels = ['Cluster 0', 'Cluster 1', 'Cluster 2', 'Cluster 3']
colors = ['#656565', '#808782', '#A6D3A0', '#D1FFD7']

# Create distplot with curve_type set to 'normal'
fig = ff.create_distplot(hist_data, group_labels, colors=colors,
                         bin_size=[0.05, 0.05, 0.05, 0.05], show_hist=True, show_rug=False)

# Add title
fig.update_layout(title_text='Valence in Peru per Mood')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="da7ef1d7-2e25-4d87-a3e0-9bf637c0c312" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("da7ef1d7-2e25-4d87-a3e0-9bf637c0c312")) {
#                     Plotly.newPlot(
#                         'da7ef1d7-2e25-4d87-a3e0-9bf637c0c312',
# ...

# %%
x1 = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 0].loc[:, 'track_danceability']
x2 = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 1].loc[:, 'track_danceability']
x3 = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 2].loc[:, 'track_danceability']
x4 = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 3].loc[:, 'track_danceability']

hist_data = [x1, x2, x3, x4]

group_labels = ['Cluster 0', 'Cluster 1', 'Cluster 2', 'Cluster 3']
colors = ['#656565', '#808782', '#A6D3A0', '#D1FFD7']

# Create distplot with curve_type set to 'normal'
fig = ff.create_distplot(hist_data, group_labels, colors=colors,
                         bin_size=[0.05, 0.05, 0.05, 0.05], show_hist=True, show_rug=False)

# Add title
fig.update_layout(title_text='Danceability in Peru per Mood')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a9ddccca-0554-44aa-ba72-9848d9081949" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a9ddccca-0554-44aa-ba72-9848d9081949")) {
#                     Plotly.newPlot(
#                         'a9ddccca-0554-44aa-ba72-9848d9081949',
# ...

# %%
peru0 = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 0]
peru0.sample(10)

# Joyful
# Out:
#     country date_extraction  ... track_danceability clusters
# 224    Peru      2020-04-24  ...              0.869        0
# 220    Peru      2020-04-23  ...              0.729        0
# 334    Peru      2020-06-03  ...              0.732        0
# 189    Peru      2020-04-04  ...              0.790        0
# 337    Peru      2020-06-06  ...              0.614        0
# 409    Peru      2020-06-11  ...              0.815        0
# 539    Peru      2020-06-11  ...              0.760        0
# 522    Peru      2020-06-11  ...              0.807        0
# 549    Peru      2020-06-11  ...              0.809        0
# 387    Peru      2020-06-11  ...              0.900        0
#
# [10 rows x 11 columns]

# %%
peru0['clusters'] = peru0['clusters'].map({ 0 : 'Chill', 1: 'Romantic', 2 : 'Party', 3 : 'Joyful'})

# %%
perusample0 = peru0.sample(10)
fig = go.Figure(data=[go.Table(
    header=dict(values=['Track name','Artist','Album','Cluster'],
                fill_color='paleturquoise',
                align='left'),
    cells=dict(values=[perusample0.track_name, perusample0.artist, perusample0.album, perusample0.clusters],
               fill_color='lavender',
               align='left'))
])
fig.update_layout(title_text='Chill tracks in Peru')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8fabd3e5-53fc-4896-89b7-246389f09897" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8fabd3e5-53fc-4896-89b7-246389f09897")) {
#                     Plotly.newPlot(
#                         '8fabd3e5-53fc-4896-89b7-246389f09897',
# ...

# %%
peru1 = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 1]
peru1.sample(10)

# Romantic
# Out:
#     country date_extraction  ... track_danceability clusters
# 305    Peru      2020-05-29  ...              0.682        1
# 217    Peru      2020-04-23  ...              0.394        1
# 468    Peru      2020-06-11  ...              0.750        1
# 272    Peru      2020-05-21  ...              0.510        1
# 465    Peru      2020-06-11  ...              0.683        1
# 530    Peru      2020-06-11  ...              0.619        1
# 348    Peru      2020-06-09  ...              0.501        1
# 365    Peru      2020-06-11  ...              0.654        1
# 396    Peru      2020-06-11  ...              0.710        1
# 22     Peru      2020-01-06  ...              0.705        1
#
# [10 rows x 11 columns]

# %%
peru1['clusters'] = peru1['clusters'].map({ 0 : 'Chill', 1: 'Romantic', 2 : 'Party', 3 : 'Joyful'})

# %%
perusample1 = peru1.sample(10)
fig = go.Figure(data=[go.Table(
    header=dict(values=['Track name','Artist','Album','Cluster'],
                fill_color='paleturquoise',
                align='left'),
    cells=dict(values=[perusample1.track_name, perusample1.artist, perusample1.album, perusample1.clusters],
               fill_color='lavender',
               align='left'))
])
fig.update_layout(title_text='Romantic tracks in Peru')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3df2f7f1-cfc3-4901-b9f6-2fe6d4a05d8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3df2f7f1-cfc3-4901-b9f6-2fe6d4a05d8c")) {
#                     Plotly.newPlot(
#                         '3df2f7f1-cfc3-4901-b9f6-2fe6d4a05d8c',
# ...

# %%
peru2 = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 2]
peru2.sample(10)

# Party
# Out:
#     country date_extraction  ... track_danceability clusters
# 382    Peru      2020-06-11  ...              0.885        2
# 139    Peru      2020-03-15  ...              0.616        2
# 504    Peru      2020-06-11  ...              0.810        2
# 184    Peru      2020-04-02  ...              0.722        2
# 244    Peru      2020-05-07  ...              0.742        2
# 335    Peru      2020-06-04  ...              0.880        2
# 268    Peru      2020-05-20  ...              0.856        2
# 540    Peru      2020-06-11  ...              0.896        2
# 53     Peru      2020-01-26  ...              0.842        2
# 395    Peru      2020-06-11  ...              0.806        2
#
# [10 rows x 11 columns]

# %%
peru3 = df_peru_results.loc[df_peru_results.\
     loc[:, 'clusters'] == 3]
peru3.sample(10)

#
# Out:
#     country date_extraction  ... track_danceability clusters
# 426    Peru      2020-06-11  ...              0.734        3
# 208    Peru      2020-04-15  ...              0.761        3
# 353    Peru      2020-06-10  ...              0.637        3
# 68     Peru      2020-02-06  ...              0.699        3
# 308    Peru      2020-05-29  ...              0.231        3
# 130    Peru      2020-03-13  ...              0.789        3
# 301    Peru      2020-05-29  ...              0.723        3
# 117    Peru      2020-03-04  ...              0.817        3
# 62     Peru      2020-02-02  ...              0.861        3
# 355    Peru      2020-06-10  ...              0.865        3
#
# [10 rows x 11 columns]

# %% [markdown]
# ### Time Line of Peru

# %%
from pymongo import MongoClient
import pprint

#pd.set_option('display.max_columns', 100)

# %%
client = MongoClient('mongodb://da-mongo:pucp-da-spotify-2020@18.205.192.71:27017/spotifydb')
client.spotifydb.list_collection_names()
pprint.pprint(client.spotifydb.tracks.find_one())
# Out:
# {'_id': ObjectId('5ef006551d7415746edc2d1d'),
#  'album': 'Dance Monkey',
#  'artist': 'Tones And I',
#  'country': 'Global',
#  'date_extraction': '2020-01-01',
#  'duration_ms': 209754,
#  'explicit': False,
#  'streams': 6155025,
#  'track_acousticness': 0.688,
#  'track_danceability': 0.825,
#  'track_energy': 0.593,
#  'track_id': '1rgnBhdG2JDFTbYkYRZAku',
#  'track_instrumentalness': 0.000161,
#  'track_key': 6.0,
#  'track_liveness': 0.17,
#  'track_loudness': -6.401,
#  'track_mode': 0.0,
#  'track_name': 'Dance Monkey',
#  'track_speechiness': 0.0988,
#  'track_tempo': 98.07799999999999,
#  'track_valence': 0.54}

# %%
df_tracks_columns = ['country', 'date_extraction', 'track_id', 'streams', 'album', 'artist',
       'duration_ms', 'explicit', 'track_name', 'track_danceability',
       'track_energy', 'track_key', 'track_loudness', 'track_mode',
       'track_speechiness', 'track_acousticness', 'track_instrumentalness',
       'track_liveness', 'track_valence', 'track_tempo']

# %%
df_tracks = pd.DataFrame(list(client.spotifydb.tracks.find()), columns=df_tracks_columns)

# %%
df_peru = df_tracks.loc[df_tracks['country'] == 'Peru']

# %%
df_peru.to_csv('peru_history.csv')

# %%
df_peru = pd.read_csv('https://dl-ta-dataset.s3.amazonaws.com/peru_history.csv')

# %%
df_peru = df_tracks.loc[df_tracks['country'] == 'Peru']
df_peru_valence = df_peru.loc[:, ['date_extraction', 'track_valence']]
df_peru_valence.loc[:, 'date_extraction'] = df_peru_valence.loc[:, 'date_extraction'].astype('datetime64[ns]')

# %%
df_peru_valence_weekly = df_peru_valence.resample('W-Mon', closed='right', label='right', on='date_extraction').mean()

# %%
df_peru_valence_weekly = df_peru_valence_weekly.reset_index()

df_peru_valence_weekly
# Out:
#    date_extraction  track_valence
# 0       2020-01-06       0.665960
# 1       2020-01-13       0.662229
# 2       2020-01-20       0.669458
# 3       2020-01-27       0.667886
# 4       2020-02-03       0.669860
# 5       2020-02-10       0.671121
# 6       2020-02-17       0.668462
# 7       2020-02-24       0.663256
# 8       2020-03-02       0.657725
# 9       2020-03-09       0.659965
# 10      2020-03-16       0.662160
# 11      2020-03-23       0.654460
# 12      2020-03-30       0.656868
# 13      2020-04-06       0.654975
# 14      2020-04-13       0.649734
# 15      2020-04-20       0.651129
# 16      2020-04-27       0.652976
# 17      2020-05-04       0.652390
# 18      2020-05-11       0.654033
# 19      2020-05-18       0.648159
# 20      2020-05-25       0.645049
# 21      2020-06-01       0.641777
# 22      2020-06-08       0.642611
# 23      2020-06-15       0.642637

# %%
fig = px.line(df_peru_valence_weekly, x='date_extraction', y='track_valence', title='Valence over time')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cb61bdd9-02bb-43fe-bdc7-05257bf0d919" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cb61bdd9-02bb-43fe-bdc7-05257bf0d919")) {
#                     Plotly.newPlot(
#                         'cb61bdd9-02bb-43fe-bdc7-05257bf0d919',
# ...

# %% [markdown]
# ### Amount of songs per cluster since January 2020

# %%
df_stacked_bar_peru = df_peru.join(df_peru_results.set_index('track_id'), on='track_id', rsuffix='_df_peru').loc[:, ['date_extraction', 'track_id', 'clusters']]
df_stacked_bar_peru.loc[:, 'date_extraction'] = df_stacked_bar_peru.loc[:, 'date_extraction'].astype('datetime64[ns]')
df_stacked_bar_peru.reset_index(inplace=True, drop=True)

# %%
df_stacked_bar_peru.loc[df_stacked_bar_peru.loc[:, 'clusters'].isnull()]
# Out:
#       date_extraction                track_id  clusters
# 20560      2020-05-29  0oQc0F6KUE7QY7k5TU6bic       NaN

# %%
df_stacked_bar_peru.drop(index=20560, inplace=True)
df_stacked_bar_peru.reset_index(inplace=True, drop=True)

# %%
df_stacked_bar_peru.loc[df_stacked_bar_peru.loc[:, 'clusters'].isnull()]
# Out:
# Empty DataFrame
# Columns: [date_extraction, track_id, clusters]
# Index: []

# %%
df_stacked_bar_peru.loc[:, 'clusters'] = df_stacked_bar_peru.loc[:, 'clusters'].astype(int)

# %%
df_stacked_bar_peru = df_stacked_bar_peru.groupby(by=['date_extraction', 'clusters'], as_index=False).count()
df_stacked_bar_peru
# Out:
#     date_extraction  clusters  track_id
# 0        2020-01-01         0        48
# 1        2020-01-01         1        10
# 2        2020-01-01         2       106
# 3        2020-01-01         3        36
# 4        2020-01-02         0        44
# ..              ...       ...       ...
# 459      2020-06-10         3        44
# 460      2020-06-11         0        42
# 461      2020-06-11         1        19
# 462      2020-06-11         2        95
# 463      2020-06-11         3        44
#
# [464 rows x 3 columns]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=df_stacked_bar_peru.loc[df_stacked_bar_peru.loc[:, 'clusters'] == 0].loc[:, 'date_extraction'], y=df_stacked_bar_peru.loc[df_stacked_bar_peru.loc[:, 'clusters'] == 0].loc[:, 'track_id'],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5, color='#AFC2D5'),
    stackgroup='one' # define stack group
))
fig.add_trace(go.Scatter(
    x=df_stacked_bar_peru.loc[df_stacked_bar_peru.loc[:, 'clusters'] == 1].loc[:, 'date_extraction'], y=df_stacked_bar_peru.loc[df_stacked_bar_peru.loc[:, 'clusters'] == 1].loc[:, 'track_id'],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5, color='#CCDDD3'),
    stackgroup='one'
))
fig.add_trace(go.Scatter(
    x=df_stacked_bar_peru.loc[df_stacked_bar_peru.loc[:, 'clusters'] == 2].loc[:, 'date_extraction'], y=df_stacked_bar_peru.loc[df_stacked_bar_peru.loc[:, 'clusters'] == 2].loc[:, 'track_id'],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5, color='#FFF9A5'),
    stackgroup='one'
))
fig.add_trace(go.Scatter(
    x=df_stacked_bar_peru.loc[df_stacked_bar_peru.loc[:, 'clusters'] == 3].loc[:, 'date_extraction'], y=df_stacked_bar_peru.loc[df_stacked_bar_peru.loc[:, 'clusters'] == 3].loc[:, 'track_id'],
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5, color='#B48B7D'),
    stackgroup='one'
))

#fig.update_layout(yaxis_range=(0, 100))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1ed3a211-d536-4155-b96f-c2c3ce3ef33b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1ed3a211-d536-4155-b96f-c2c3ce3ef33b")) {
#                     Plotly.newPlot(
#                         '1ed3a211-d536-4155-b96f-c2c3ce3ef33b',
# ...

# %%
fig = px.line(df_stacked_bar_peru.loc[df_stacked_bar_peru.loc[:, 'clusters'] == 0], x='date_extraction', y='track_id', title='Romantic Tracks')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5d2b13f5-d614-4d25-92b3-c922c5c137dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5d2b13f5-d614-4d25-92b3-c922c5c137dc")) {
#                     Plotly.newPlot(
#                         '5d2b13f5-d614-4d25-92b3-c922c5c137dc',
# ...

# %%
fig = px.line(df_stacked_bar_peru.loc[df_stacked_bar_peru.loc[:, 'clusters'] == 1], x='date_extraction', y='track_id', title='Chill Tracks')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f215b622-4bcd-4c90-81d2-459c654e4b42" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f215b622-4bcd-4c90-81d2-459c654e4b42")) {
#                     Plotly.newPlot(
#                         'f215b622-4bcd-4c90-81d2-459c654e4b42',
# ...

# %%
fig = px.line(df_stacked_bar_peru.loc[df_stacked_bar_peru.loc[:, 'clusters'] == 2], x='date_extraction', y='track_id', title='Party tracks')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fa585eb9-5b13-4d4d-85d7-5c30d8d44486" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fa585eb9-5b13-4d4d-85d7-5c30d8d44486")) {
#                     Plotly.newPlot(
#                         'fa585eb9-5b13-4d4d-85d7-5c30d8d44486',
# ...

# %%
fig = px.line(df_stacked_bar_peru.loc[df_stacked_bar_peru.loc[:, 'clusters'] == 3], x='date_extraction', y='track_id', title='Joyful tracks')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9eb27810-9496-40ac-9d34-d1b5df753e14" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9eb27810-9496-40ac-9d34-d1b5df753e14")) {
#                     Plotly.newPlot(
#                         '9eb27810-9496-40ac-9d34-d1b5df753e14',
# ...

# %%
#Agrupar por clusters

# %%
df_stacked_bar_peru = df_peru.join(df_peru_results.set_index('track_id'), on='track_id', rsuffix='_df_peru').loc[:, ['date_extraction', 'track_id', 'clusters']]
df_stacked_bar_peru.loc[:, 'date_extraction'] = df_stacked_bar_peru.loc[:, 'date_extraction'].astype('datetime64[ns]')
df_stacked_bar_peru.reset_index(inplace=True, drop=True)
df_stacked_bar_peru.drop(index=20560, inplace=True)
df_stacked_bar_peru.reset_index(inplace=True, drop=True)
df_stacked_bar_peru.loc[:, 'clusters'] = df_stacked_bar_peru.loc[:, 'clusters'].astype(int)
df_stacked_bar_peru['month'] = pd.DatetimeIndex(df_stacked_bar_peru['date_extraction']).month

# %%
df_stacked_bar_peru
# Out:
#       date_extraction                track_id  clusters  month
# 0          2020-01-01  7k4t7uLgtOxPwTpFmtJNTY         0      1
# 1          2020-01-01  6mAN61JH0dzyZpWslS11jy         2      1
# 2          2020-01-01  5stPVcRqb4qixbafP9e8lt         1      1
# 3          2020-01-01  6cy3ki60hLwimwIje7tALf         2      1
# 4          2020-01-01  2ksOAxtIxY8yElEWw8RhgK         2      1
# ...               ...                     ...       ...    ...
# 23194      2020-06-11  16wAOAZ2OkqoIDN7TpChjR         3      6
# 23195      2020-06-11  1GBLO0NFODuL31A5fgw0uR         2      6
# 23196      2020-06-11  2hdhH9YsYQInj4NYU75XZZ         2      6
# 23197      2020-06-11  5omgFpiMt1CGHjQGfkwzvz         1      6
# 23198      2020-06-11  0FSuo71145fPvjrnjkwIU8         2      6
#
# [23199 rows x 4 columns]

# %%
df_stacked_bar_peru = df_stacked_bar_peru.groupby(by=['month', 'clusters'], as_index=False).count()
df_stacked_bar_peru
# Out:
#     month  clusters  date_extraction  track_id
# 0       1         0             1283      1283
# 1       1         1              443       443
# 2       1         2             3278      3278
# 3       1         3             1196      1196
# 4       2         0              715       715
# 5       2         1              220       220
# 6       2         2             1821      1821
# 7       2         3              644       644
# 8       3         0              495       495
# 9       3         1              130       130
# 10      3         2             1239      1239
# 11      3         3              536       536
# 12      4         0              653       653
# 13      4         1              281       281
# 14      4         2             1736      1736
# 15      4         3              730       730
# 16      5         0             1097      1097
# 17      5         1              505       505
# 18      5         2             2754      2754
# ...

# %%
df_stacked_bar_peru['month'] = df_stacked_bar_peru['month'].map({ 1 : 'January', 2: 'February', 3 : 'March', 4 : 'April', 5: 'May', 6: 'June'})

# %%
df_stacked_bar_peru['clusters'] = df_stacked_bar_peru['clusters'].map({ 0 : 'Romantic', 1: 'Chill', 2 : 'Party', 3 : 'Joyful'})

# %%
df_stacked_bar_peru
# Out:
#        month  clusters  date_extraction  track_id
# 0    January  Romantic             1283      1283
# 1    January     Chill              443       443
# 2    January     Party             3278      3278
# 3    January    Joyful             1196      1196
# 4   February  Romantic              715       715
# 5   February     Chill              220       220
# 6   February     Party             1821      1821
# 7   February    Joyful              644       644
# 8      March  Romantic              495       495
# 9      March     Chill              130       130
# 10     March     Party             1239      1239
# 11     March    Joyful              536       536
# 12     April  Romantic              653       653
# 13     April     Chill              281       281
# 14     April     Party             1736      1736
# 15     April    Joyful              730       730
# 16       May  Romantic             1097      1097
# 17       May     Chill              505       505
# ...

# %%
import plotly.express as px
#df = px.data.tips()
fig = px.bar(df_stacked_bar_peru, x="month", y="track_id", color='clusters', barmode="group",labels={'track_id':'# Tracks','month':'Timeline'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d422885b-5c85-49a2-a54f-fccd80b2c3d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d422885b-5c85-49a2-a54f-fccd80b2c3d2")) {
#                     Plotly.newPlot(
#                         'd422885b-5c85-49a2-a54f-fccd80b2c3d2',
# ...

# %%
peru_romantic = peru0.sample(10)
peru_chill = peru1.sample(10)
peru_party = peru2.sample(10)
peru_joyful = peru3.sample(10)

# %%
peru_sample = pd.concat([peru_romantic,peru_chill,peru_party,peru_joyful])

# %%
peru_romantic['clusters'] = peru_romantic['clusters'].map({ 0 : 'Chill', 1: 'Romantic', 2 : 'Party', 3 : 'Joyful'})
#['Cluster 0: Chill','Cluster 1: Romantic','Cluster 2: Party','Cluster 3: Joyful']
#{ 0 : 'Romantic', 1: 'Chill', 2 : 'Party', 3 : 'Joyful'}

# %%
import plotly.graph_objects as go


fig = go.Figure(data=[go.Table(
    header=dict(values=['Track name','Artist','Album','Cluster'],
                fill_color='paleturquoise',
                align='left'),
    cells=dict(values=[peru_sample.track_name, peru_sample.artist, peru_sample.album, peru_sample.clusters],
               fill_color='lavender',
               align='left'))
])

fig.show()

# %%
import plotly.graph_objects as go


fig = go.Figure(data=[go.Table(
    header=dict(values=['Track name','Artist','Album','Cluster'],
                fill_color='paleturquoise',
                align='left'),
    cells=dict(values=[peru_sample.track_name, peru_sample.artist, peru_sample.album, peru_sample.clusters],
               fill_color='lavender',
               align='left'))
])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="57642ad3-f534-41a4-8a23-c1bb002ce471" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("57642ad3-f534-41a4-8a23-c1bb002ce471")) {
#                     Plotly.newPlot(
#                         '57642ad3-f534-41a4-8a23-c1bb002ce471',
# ...

# %%
df_southamerica_results = pd.read_csv('https://dl-ta-dataset.s3.amazonaws.com/southamerica_results.csv')
df_southamerica = pd.read_csv('https://dl-ta-dataset.s3.amazonaws.com/southamerica_history.csv')

# %%
df_stacked_bar_southamerica = df_southamerica.join(df_southamerica_results.set_index('track_id'), on='track_id', rsuffix='_df_southamerica').loc[:, ['date_extraction', 'track_id', 'clusters']]
df_stacked_bar_southamerica.loc[:, 'date_extraction'] = df_stacked_bar_southamerica.loc[:, 'date_extraction'].astype('datetime64[ns]')
df_stacked_bar_southamerica.reset_index(inplace=True, drop=True)
df_stacked_bar_southamerica.loc[:, 'clusters'] = df_stacked_bar_southamerica.loc[:, 'clusters'].astype(int)
df_stacked_bar_southamerica = df_stacked_bar_southamerica.groupby(by=['date_extraction', 'clusters'], as_index=False).count()

# %%
df_stacked_bar_southamerica
# Out:
#     date_extraction  clusters  track_id
# 0        2020-01-01         0       110
# 1        2020-01-01         1       158
# 2        2020-01-01         2        11
# 3        2020-01-01         3         7
# 4        2020-01-02         0         2
# ..              ...       ...       ...
# 444      2020-06-10         3         5
# 445      2020-06-11         0       139
# 446      2020-06-11         1       237
# 447      2020-06-11         2       146
# 448      2020-06-11         3        62
#
# [449 rows x 3 columns]

# %%
df_stacked_bar_southamerica = df_southamerica.join(df_southamerica_results.set_index('track_id'), on='track_id', rsuffix='_df_southamerica').loc[:, ['date_extraction', 'track_id', 'clusters']]

# %%
df_stacked_bar_southamerica
# Out:
#      date_extraction                track_id  clusters
# 0         2020-01-01  3sJGioieL1x7wBEWoUg60L         1
# 1         2020-01-01  2ZixSR7OKIpdPUk4dwOekn         1
# 2         2020-01-01  4EOTkRt48d1Eu31V2o4mNw         1
# 3         2020-01-01  7ovvopa6MpiwzPOzY2TkVi         0
# 4         2020-01-01  76BnEV7y0FIyDodcCt9sxC         1
# ...              ...                     ...       ...
# 2161      2020-06-11  43NqTeL8pgBxKHPMiJKUP5         1
# 2162      2020-06-11  4EJHKSnHENfjOxXWryyNtL         2
# 2163      2020-06-11  5Bi9Cq5oVFy1OtUgecbegZ         2
# 2164      2020-06-11  3ewwb5s3WHYqEdkBnwKlTS         1
# 2165      2020-06-11  2Fxmhks0bxGSBdJ92vM42m         2
#
# [2166 rows x 3 columns]

# %%
df_stacked_bar_southamerica.loc[:, 'date_extraction'] = df_stacked_bar_southamerica.loc[:, 'date_extraction'].astype('datetime64[ns]')

# %%
df_stacked_bar_southamerica.reset_index(inplace=True, drop=True)

# %%
df_stacked_bar_southamerica_daily = df_stacked_bar_southamerica.groupby(by=['date_extraction', 'clusters'], as_index=False).count()

# %%
df_stacked_bar_southamerica_daily
# Out:
#     date_extraction  clusters  track_id
# 0        2020-01-01         0       110
# 1        2020-01-01         1       158
# 2        2020-01-01         2        11
# 3        2020-01-01         3         7
# 4        2020-01-02         0         2
# ..              ...       ...       ...
# 444      2020-06-10         3         5
# 445      2020-06-11         0       139
# 446      2020-06-11         1       237
# 447      2020-06-11         2       146
# 448      2020-06-11         3        62
#
# [449 rows x 3 columns]

# %%
df_stacked_bar_southamerica = df_southamerica.join(df_southamerica_results.set_index('track_id'), on='track_id', rsuffix='_df_southamerica').loc[:, ['date_extraction', 'track_id', 'clusters']]
df_stacked_bar_southamerica.loc[:, 'date_extraction'] = df_stacked_bar_southamerica.loc[:, 'date_extraction'].astype('datetime64[ns]')
df_stacked_bar_southamerica.reset_index(inplace=True, drop=True)
#df_stacked_bar_southamerica.drop(index=20560, inplace=True)
#df_stacked_bar_southamerica.reset_index(inplace=True, drop=True)
#df_stacked_bar_southamerica.loc[:, 'clusters'] = df_stacked_bar_southamerica.loc[:, 'clusters'].astype(int)
df_stacked_bar_southamerica_daily = df_stacked_bar_southamerica.groupby(by=['date_extraction', 'clusters'], as_index=False).count()
df_stacked_bar_southamerica['month'] = pd.DatetimeIndex(df_stacked_bar_southamerica['date_extraction']).month
df_stacked_bar_southamerica = df_stacked_bar_southamerica.groupby(by=['month', 'clusters'], as_index=False).count()
df_stacked_bar_southamerica['month'] = df_stacked_bar_southamerica['month'].map({ 1 : 'January', 2: 'February', 3 : 'March', 4 : 'April', 5: 'May', 6: 'June'})
df_stacked_bar_southamerica['clusters'] = df_stacked_bar_southamerica['clusters'].map({ 0 : 'Joyful', 1: 'Party', 2 : 'Chill', 3 : 'Romantic'})

fig_stacked_southamerica = px.bar(df_stacked_bar_southamerica, x="month", y="track_id", color='clusters', barmode="group",labels={'track_id':'Tracks','month':'Timeline'})
fig_stacked_southamerica.update_layout(title_text='Tracks per cluster in Southamerica Timeline')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4dc911f6-9a0b-4591-b7ec-3c073426c2b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4dc911f6-9a0b-4591-b7ec-3c073426c2b2")) {
#                     Plotly.newPlot(
#                         '4dc911f6-9a0b-4591-b7ec-3c073426c2b2',
# ...

# %%
df_stacked_bar_southamerica_daily.head(10)
# Out:
#   date_extraction  clusters  track_id
# 0      2020-01-01         0       110
# 1      2020-01-01         1       158
# 2      2020-01-01         2        11
# 3      2020-01-01         3         7
# 4      2020-01-02         0         2
# 5      2020-01-03         0         1
# 6      2020-01-03         1         1
# 7      2020-01-03         2         1
# 8      2020-01-04         1         2
# 9      2020-01-04         2         1
