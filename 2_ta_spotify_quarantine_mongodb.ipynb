# %% [markdown]
# # Saving Data Extracted in MongoDB

# %% [markdown]
# <p>Students:</p>
# <ul>
#     <li> Ronie Arauco </li>
#     <li> Handry Guillen </li>
# <ul>

# %% [markdown]
# <p>Spotify Music analysis through KDD data analysis using the Spotify Web API aims to explore the relation between the music taste of people and the context we are living currently.</p>
# <p>The request we are doing goes through the Spotfiy Client Workflow and the image below explains how it works.</p>

# %% [markdown]
# ## 1. MongoDB

# %% [markdown]
# ### 1.1. Importing Libraries

# %%
import numpy as np
import pandas as pd
import datetime
from pymongo import MongoClient
import pprint

pd.set_option('display.max_columns', 100)

# %% [markdown]
# ### 1.2. Reading Extracted Data

# %%
# Just for Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/data-analysis-ta-2020/dataset_tracks.csv')

# %%
df.shape
# Out:
# (1330714, 20)

# %% [markdown]
# ### 1.3. Log in to MongoDB

# %%
client = MongoClient('mongodb://da-mongo:pucp-da-spotify-2020@18.232.49.3:27017/spotifydb')
# Out:
# MongoClient(host=['18.232.49.3:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
client.spotifydb.list_collection_names()
# Out:
# ['testing_collection', 'tracks']

# %%
pprint.pprint(client.spotifydb.testing_collection.find_one())
# Out:
# {'_id': ObjectId('5ef0017a4d01295d4555b909'),
#  'lastname': 'arauco',
#  'name': 'ronie'}

# %% [markdown]
# ### 1.4. Writing in DB

# %%
#records_ = df.to_dict(orient='records')

# %%
#result = db.tracks.insert_many(records_)

# %%
pprint.pprint(client.spotifydb.tracks.find_one())
# Out:
# {'_id': ObjectId('5ef006551d7415746edc2d1d'),
#  'album': 'Dance Monkey',
#  'artist': 'Tones And I',
#  'country': 'Global',
#  'date_extraction': '2020-01-01',
#  'duration_ms': 209754,
#  'explicit': False,
#  'streams': 6155025,
#  'track_acousticness': 0.688,
#  'track_danceability': 0.825,
#  'track_energy': 0.593,
#  'track_id': '1rgnBhdG2JDFTbYkYRZAku',
#  'track_instrumentalness': 0.000161,
#  'track_key': 6.0,
#  'track_liveness': 0.17,
#  'track_loudness': -6.401,
#  'track_mode': 0.0,
#  'track_name': 'Dance Monkey',
#  'track_speechiness': 0.0988,
#  'track_tempo': 98.07799999999999,
#  'track_valence': 0.54}
